# %% [markdown]
# # Week 6 — BTB vs the Compass Bagua
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jc7k/fengshui/blob/main/notebooks/Week_6_BTB_Contrast.ipynb)
#
# Two maps of the same home, often disagreeing. Read `07-Week-6-BTB-Contrast/Module-Guide.md` first.

# %%
# --- Environment bootstrap (run me first) ---
import os, sys

GITHUB_USERNAME = "jc7k"  # change this only if you saved your own copy of the repo

try:
    import google.colab  # noqa: F401
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    os.system(f"git clone -q https://github.com/{GITHUB_USERNAME}/fengshui.git")
    sys.path.insert(0, "fengshui/src")
else:
    # Local / VS Code / headless: the notebook lives in notebooks/, src is next door.
    sys.path.insert(0, os.path.abspath(os.path.join("..", "src")))

import matplotlib.pyplot as plt
print("Bootstrap OK —", "Colab" if IN_COLAB else "local")

# %% [markdown]
# ## 1. Two overlays, one home

# %%
import bagua, homes, viz

home = homes.load_home('sunny_studio')
door_wall = homes.find_feature(home, 'door')['wall']
compass_grid = bagua.compass_overlay()
btb_grid = bagua.btb_overlay(door_wall)
viz.plot_school_comparison(home, compass_grid, btb_grid)
plt.show()

# %% [markdown]
# ## 2. ✏️ YOUR CELL — the diff table
# Walk the 3x3 sectors and list where the compass school and BTB assign *different* life areas to the same physical spot.

# %%
conflicts = []
for r in range(3):
    for c in range(3):
        if compass_grid[r][c] != btb_grid[r][c]:
            conflicts.append((compass_grid[r][c], btb_grid[r][c]))
print(f'{len(conflicts)} of 9 sectors disagree:')
for comp, btb in conflicts:
    print(f'   compass says {comp:>14} | BTB says {btb}')

# %% [markdown]
# ## 3. ✅ The two schools really do conflict
# A non-empty diff is the whole point of this week.

# %%
assert len(conflicts) > 0, 'expected the schools to disagree'
print('✅ the schools disagree on', len(conflicts), 'sectors — exactly as expected')

# %% [markdown]
# Fill in your Lab-Notes & Reflection. ➡️ The capstone brings *all* the schools together.
