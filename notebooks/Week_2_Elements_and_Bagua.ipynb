# %% [markdown]
# # Week 2 — The Five Elements Engine
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jc7k/fengshui/blob/main/notebooks/Week_2_Elements_and_Bagua.ipynb)
#
# Build the Wu Xing cycles and upgrade Week 1's naive tips into ones that explain *why*. Read `03-Week-2-Elements-and-Bagua/Module-Guide.md` first.

# %%
# --- Environment bootstrap (run me first) ---
import os, sys

GITHUB_USERNAME = "jc7k"  # change this only if you saved your own copy of the repo

try:
    import google.colab  # noqa: F401
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    os.system(f"git clone -q https://github.com/{GITHUB_USERNAME}/fengshui.git")
    sys.path.insert(0, "fengshui/src")
else:
    # Local / VS Code / headless: the notebook lives in notebooks/, src is next door.
    sys.path.insert(0, os.path.abspath(os.path.join("..", "src")))

import matplotlib.pyplot as plt
print("Bootstrap OK —", "Colab" if IN_COLAB else "local")

# %% [markdown]
# ## 1. The two cycles
# Generating (feeds) and controlling (checks).

# %%
import elements, homes

for e in elements.ELEMENTS:
    print(f"{e:>6}: generates {elements.generates(e):>6} | controls {elements.controls(e)}")

# %% [markdown]
# ## 2. ✅ Check the engine against the reference table
# Our 'accuracy': does the code reproduce the canonical Wu Xing cycles in `data/reference/wu_xing.json`?

# %%
wx = homes.load_reference('wu_xing')
gen_ok = all(elements.generates(e) == wx['generating_cycle'][e] for e in elements.ELEMENTS)
ctl_ok = all(elements.controls(e) == wx['controlling_cycle'][e] for e in elements.ELEMENTS)
print('✅' if gen_ok else '❌', 'generating cycle matches reference')
print('✅' if ctl_ok else '❌', 'controlling cycle matches reference')
assert gen_ok and ctl_ok

# %% [markdown]
# ## 3. Relationships explain a pairing

# %%
for a, b in [('Fire','Metal'), ('Water','Wood'), ('Earth','Earth')]:
    rel = elements.relationship(a, b)
    print(f"{a} vs {b}: {rel} -> {elements.RELATIONSHIP_GLOSS[rel]}")

# %% [markdown]
# ## 4. ✏️ YOUR CELL — element-aware tips
# Call `analyzer.element_tips(home)` and print each note. This is the upgrade: every tip now names the *relationship* between a room's element and its area's element.

# %%
import analyzer
home = homes.load_home('sunny_studio')
for tip in analyzer.element_tips(home):
    print('-', tip['note'])

# %% [markdown]
# ## 5. Compare: Week 1 vs Week 2 tips on the same home

# %%
print('WEEK 1 (naive):')
for t in analyzer.naive_recommendations(home): print('  -', t)
print('\nWEEK 2 (element-aware):')
for t in analyzer.element_tips(home): print('  -', t['note'])

# %% [markdown]
# Fill in your Lab-Notes & Reflection. ➡️ Week 3 makes it personal with your Kua number.
